# %%
import requests

# %%
import pandas as pd

# %%
main_file = pd.read_excel('main_pursuit_total.xlsx')

# %%
# TODO: Do a Group by and county of the pursuit numbers. 
# 1. Sort and/or filter for any that have more than 1
# 2. Calcualte the percentage of total pursuits that these "dupes" account for

# If you want to keep all the pursuits:
# - Make a new pursuit number column
# - Rename dupe agencies for examble adding a number to each dupe pursuit
# - reminder, check to see if fatalities/injuries are duplicated (things like speed won't)

# %%
main_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41185 entries, 0 to 41184
# Data columns (total 53 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Pursuit Number                        41185 non-null  int64
#  1   Initiating Date                       41185 non-null  datetime64[ns]
#  2   Initiating Time                       41185 non-null  int64
#  3   State                                 41174 non-null  object
#  4   Status of Report                      41185 non-null  object
#  5   Initiating Agency NCIC                41185 non-null  object
#  6   Terminating NCIC                      41185 non-null  object
#  7   Multi-Area/Agency Pursuit             41185 non-null  object
#  8   CHP Participation Requested           41185 non-null  object
#  9   Requestor Name                        1847 non-null   object
# ...

# %%
 grouped_file = main_file.groupby("Pursuit Number").size()

# %%
print(grouped_file)
# Out:
# Pursuit Number
# 20221        1
# 20222        1
# 20223        1
# 20224        2
# 20225        1
#             ..
# 202413759    1
# 202413760    1
# 202413761    1
# 202413762    1
# 202413763    1
# Length: 39240, dtype: int64

# %%
duplicates = grouped_file[grouped_file > 1]

# %%
print(duplicates)
# Out:
# Pursuit Number
# 20224        2
# 20226        3
# 20242        2
# 202220       3
# 202224       2
#             ..
# 202412702    2
# 202412722    2
# 202412738    2
# 202413176    3
# 202413177    2
# Length: 1451, dtype: int64

# %% [markdown]
# There are 1451 multi-agency pursuits

# %%
duplicate_rate = (1451/39240)*100

# %%
print(duplicate_rate)
# Out:
# 3.6977573904179413

# %% [markdown]
# Multi-agency pursuits account for 3.6% of all pursuits
